# %%
import pandas as pd

# %%
#create a dictionary with mixed data type
data={'name':['Tom','nick','krish','jack'],'age':[20,21,19,18],'occupation':['Ml Engineer','Software Enginner','Teacher','Researcher'],'salary':[60000,70000,80000,90000]}

# %%
data
# Out:
# {'name': ['Tom', 'nick', 'krish', 'jack'],
#  'age': [20, 21, 19, 18],
#  'occupation': ['Ml Engineer', 'Software Enginner', 'Teacher', 'Researcher'],
#  'salary': [60000, 70000, 80000, 90000]}

# %%
#create dataframe and cheeck datatype
df=pd.DataFrame(data)

# %%
print(df.dtypes)
# Out:
# name          object
# age            int64
# occupation    object
# salary         int64
# dtype: object

# %%
df
# Out:
#     name  age         occupation  salary
# 0    Tom   20        Ml Engineer   60000
# 1   nick   21  Software Enginner   70000
# 2  krish   19            Teacher   80000
# 3   jack   18         Researcher   90000

# %%
#datetime
dates=['2025-10-04','2024-11-21','2026-1-1']

# %%
#create a dataframe with a datatime column
df1=pd.DataFrame({'date':dates})

# %%
df1['date'].dtype
# Out:
# dtype('O')

# %%
timestamps=pd.to_datetime(dates, errors='coerce')
df2=pd.DataFrame({'date2':timestamps})
df2
# Out:
#        date2
# 0 2025-10-04
# 1 2024-11-21
# 2 2026-01-01

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date2   3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 156.0 bytes
