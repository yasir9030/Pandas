# %%
import pandas as pd

# %% [markdown]
# create a list of dara

# %%
data=[1,22,3,10]

# %%
data
# Out:
# [1, 22, 3, 10]

# %%
type(data)
# Out:
# list

# %%
#create a series and series is one dimension
s= pd.Series(data)
s
# Out:
# 0     1
# 1    22
# 2     3
# 3    10
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
#crate dataframe from series
df=pd.DataFrame(s,columns=['num'])

# %%
df
# Out:
#    num
# 0    1
# 1   22
# 2    3
# 3   10

# %%
#create dataframe from list
df1=pd.DataFrame(data,columns=['num'])
df1
# Out:
#    num
# 0    1
# 1   22
# 2    3
# 3   10

# %%
#dataframe to series
s2=df1['num']
s2
# Out:
# 0     1
# 1    22
# 2     3
# 3    10
# Name: num, dtype: int64

# %%
#create a series for a 2 interger
data=[[1,2],[3,4],[5,8]]
data
# Out:
# [[1, 2], [3, 4], [5, 8]]

# %%
df=pd.DataFrame(data,columns=['num1','num2'])
df
# Out:
#    num1  num2
# 0     1     2
# 1     3     4
# 2     5     8

# %%
#create a dictionary
data3={'name':['yasir','arafat','ronaldo'],
      'age':[22,25,30],
      'city ':['pabna,cumil;a,dhaka']}

# %%
data
# Out:
# {'name': ['yasir', 'arafat', 'ronaldo'],
#  'age': [22, 25, 30],
#  'city ': ['pabna,cumil;a,dhaka']}

# %%
#create a series from dictionary
num=pd.Series(data3['name'],name='name')
num
# Out:
# 0      yasir
# 1     arafat
# 2    ronaldo
# Name: name, dtype: object

# %%
data3={'name':['yasir','arafat','ronaldo'],
      'age':[22,25,30],
      'city ':['pabna','cumilla','dhaka']}
df3=pd.DataFrame(data3)
df3
# Out:
#       name  age    city
# 0    yasir   22    pabna
# 1   arafat   25  cumilla
# 2  ronaldo   30    dhaka

# %%
age_sereies=df3['age']
age_sereies
# Out:
# 0    22
# 1    25
# 2    30
# Name: age, dtype: int64
